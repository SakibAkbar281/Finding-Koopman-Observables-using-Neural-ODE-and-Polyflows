# %% [markdown]
# # **Learning Dynamics using Neural Ordinary Differential Equations**

# %% [markdown]
# ![diagram-20230411.png](attachment:diagram-20230411.png)

# %% [markdown]
# ## Introduction
# The aim of this project is to use Neural Ordinary Differential Equations (Neural ODE) to learn the unknown dynamics of a system from time series data.
#
#
# ## Problem Statement
#
# The problem at hand concerns discovering the unknown dynamics of a given dynamical system, represented by the equation $\dot{x} =f(x)$ with a specified initial condition $x(0)=x_{0}$. The data available for analysis is the time series data of $x(t)$ for the aforementioned initial condition $x_{0}$.
#
# To address this problem, we have selected the Lotka-Volterra or Predator-Prey dynamical system, described by the equations:
# $$
# \begin{align*}
# \begin{bmatrix}
# \dot{x}_{1}\\
# \dot{x}_{2}
# \end{bmatrix} & =\begin{bmatrix}
# ax_{1} -bx_{1} x_{2}\\
# cx_{1} x_{2} -dx_{2}
# \end{bmatrix} =f( x) ,\\
# \begin{bmatrix}
# x_{1}( 0)\\
# x_{2}( 0)
# \end{bmatrix} & =\begin{bmatrix}
# 1\\
# 1
# \end{bmatrix} .
# \end{align*}
# $$
# Here, the values of $a,b,c,$ and $d$ are predefined as $1.5,1,1,$ and $0.5$ respectively. However, the governing dynamics function $f(x)$ is unknown.
#
# The objective of this project is to develop a neural network that can approximate $\dot{x}_{1}$ and $\dot{x}_{2}$ from the given time series data of $x_{1} (t)$ and $x_{2} (t)$, thus allowing us to discover the unknown dynamics $f(x)$.

# %% [markdown]
# ## Method

# %% [markdown]
# ### 1. Generating Data

# %% [markdown]
# #### Importing Necessary modules

# %%
# %pip install torchdiffeq
# Out:
# Requirement already satisfied: torchdiffeq in /home/shahriar/anaconda3/lib/python3.9/site-packages (0.2.3)
# Requirement already satisfied: scipy>=1.4.0 in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torchdiffeq) (1.7.3)
# Requirement already satisfied: torch>=1.3.0 in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torchdiffeq) (2.0.0)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /home/shahriar/anaconda3/lib/python3.9/site-packages (from scipy>=1.4.0->torchdiffeq) (1.22.4)
# Requirement already satisfied: typing-extensions in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torch>=1.3.0->torchdiffeq) (4.1.1)
# Requirement already satisfied: jinja2 in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torch>=1.3.0->torchdiffeq) (2.11.3)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torch>=1.3.0->torchdiffeq) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torch>=1.3.0->torchdiffeq) (11.10.3.66)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torch>=1.3.0->torchdiffeq) (10.2.10.91)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torch>=1.3.0->torchdiffeq) (11.7.91)
# Requirement already satisfied: filelock in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torch>=1.3.0->torchdiffeq) (3.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torch>=1.3.0->torchdiffeq) (11.7.99)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torch>=1.3.0->torchdiffeq) (10.9.0.58)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torch>=1.3.0->torchdiffeq) (11.7.99)
# Requirement already satisfied: triton==2.0.0 in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torch>=1.3.0->torchdiffeq) (2.0.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torch>=1.3.0->torchdiffeq) (11.7.101)
# Requirement already satisfied: sympy in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torch>=1.3.0->torchdiffeq) (1.10.1)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torch>=1.3.0->torchdiffeq) (2.14.3)
# Requirement already satisfied: networkx in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torch>=1.3.0->torchdiffeq) (2.7.1)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torch>=1.3.0->torchdiffeq) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/shahriar/anaconda3/lib/python3.9/site-packages (from torch>=1.3.0->torchdiffeq) (11.7.4.91)
# Requirement already satisfied: setuptools in /home/shahriar/anaconda3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.3.0->torchdiffeq) (67.6.1)
# Requirement already satisfied: wheel in /home/shahriar/anaconda3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.3.0->torchdiffeq) (0.37.1)
# Requirement already satisfied: lit in /home/shahriar/anaconda3/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.3.0->torchdiffeq) (16.0.0)
# Requirement already satisfied: cmake in /home/shahriar/anaconda3/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.3.0->torchdiffeq) (3.26.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/shahriar/anaconda3/lib/python3.9/site-packages (from jinja2->torch>=1.3.0->torchdiffeq) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /home/shahriar/anaconda3/lib/python3.9/site-packages (from sympy->torch>=1.3.0->torchdiffeq) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import numpy as np
from tqdm.notebook import tqdm
import time

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Defining ODE Solver

# %% [markdown]
# In our study, we employed the RK4 method for numerical integration to obtain the time series data from the given dynamics function. The solution of the initial value problem for $\dot{x} = f(x,\tau)$, with an initial condition of $x(0) = x_{0}$, can be expressed as:
#
# \begin{align*}
# x(t) & = x_{0} + \int _{0}^{t} f(x,\tau) d\tau.
# \end{align*}
#
# In the RK4 method, the integral $\int _{0}^{t} f(x,\tau) d\tau$ is approximated using the following formula:
#
# \begin{align*}
# \int_{0}^{t} f(x) d\tau & \approx \frac{1}{6}[ k_{1} + 2(k_{2} + k_{3}) + k_{4} ] \Delta t, \\
# k_{1} & = f(t,x), \\
# k_{2} & = f\left(t + \frac{1}{2} \Delta t, x + \frac{\Delta t}{2} k_{1}\right), \\
# k_{3} & = f\left(t + \frac{1}{2} \Delta t, x + \frac{\Delta t}{2} k_{2}\right), \\
# k_{4} & = f(t + \Delta t, x + \Delta t k_{2}).
# \end{align*}
#
# In this approximation, $k_{1}$, $k_{2}$, $k_{3}$, and $k_{4}$ are intermediate values that are computed using the dynamics function $f(x,\tau)$ and the current state of the system $x$ at specific time steps, and $\Delta t$ denotes the time step. The RK4 method is widely used due to its accuracy and ability to handle non-linear systems.

# %%
def rk4(func, t, dt, y):
  _one_sixth = 1/6
  half_dt = dt * 0.5

  k1 = func(t, y)
  k2 = func(t + half_dt, y + half_dt * k1)
  k3 = func(t + half_dt, y + half_dt * k2)
  k4 = func(t + dt, y + dt * k3)
  
  return (k1 + 2 * (k2 + k3) + k4) * dt * _one_sixth

# %%
class NeuralODE(nn.Module):
  def __init__(self, func):
    super().__init__()
    self.func = func

  def forward(self, y0, t, solver):
    solution = torch.empty(len(t), *y0.shape, dtype=y0.dtype, device=y0.device)
    solution[0] = y0

    j = 1
    for t0, t1 in zip(t[:-1], t[1:]):
      dy = solver(self.func, t0, t1 - t0, y0)
      y1 = y0 + dy
      solution[j] = y1
      j += 1
      y0 = y1
    return solution
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/shahriar/OneDrive/_SAKIB'S RPI/learning-dynamics-from-data/neural_ode.ipynb Cell 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/shahriar/OneDrive/_SAKIB%27S%20RPI/learning-dynamics-from-data/neural_ode.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> class NeuralODE(nn.Module):
#       <a href='vscode-notebook-cell:/home/shahriar/OneDrive/_SAKIB%27S%20RPI/learning-dynamics-from-data/neural_ode.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a>   def __init__(self, func):
#       <a href='vscode-notebook-cell:/home/shahriar/OneDrive/_SAKIB%27S%20RPI/learning-dynamics-from-data/neural_ode.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a>     super().__init__()
#
# NameError: name 'nn' is not defined

# %% [markdown]
# #### Lotka-Volterra

# %%
# generate toy dataset
data_size = 1000
true_y0 = torch.tensor([[1., 1.]]).cuda()
t = torch.linspace(0., 10., data_size).cuda()

# %%
a = 1.5
b = 1
c = 1
d = 0.5
class Lambda(nn.Module):
  def forward(self, t, y):
    y1 = y[0,0]
    y2 = y[0,1]
    return torch.tensor([[a*y1 - b*y1*y2, c*y1*y2- d*y2]]).cuda()

with torch.no_grad():
  node = NeuralODE(func=Lambda()).cuda()
  true_y = node(y0=true_y0, t=t, solver=rk4)

# %% [markdown]
# ## Adding noise to the data

# %%
# specify the standard deviation of the noise
noise_stddev = 0.01

# generate random noise tensor with the same shape as true_y
noise = (torch.randn(true_y.shape) * noise_stddev).cuda()

# add the noise to true_y
noisy_y = true_y + noise

# %% [markdown]
# ## Visualizing the datasets

# %%
def visualize(true_y, noisy_y=None, pred_y=None):
  fig = plt.figure(figsize=(12, 6), facecolor='white')
  ax = fig.add_subplot(121)
  ax.set_title('Phase Portrait')
  ax.set_xlabel('$x_1$')
  ax.set_ylabel('$x_2$')
  ax2 = fig.add_subplot(122)
  ax2.set_title('Trajectories')
  ax2.set_xlabel('t')
  ax2.set_ylabel('$x_1$,$x_2$')

  ax2.plot(t.cpu().numpy(), true_y.cpu().numpy()[:, 0, 0], t.cpu().numpy(), true_y.cpu().numpy()[:, 0, 1], 'g-')
  ax2.legend(['y1','y2'])



  ax.plot(true_y.cpu().numpy()[:, 0, 0], true_y.cpu().numpy()[:, 0, 1], 'green', label='true trajectory')

  if noisy_y is not None:
    ax.scatter(noisy_y.cpu().numpy()[:, 0, 0], noisy_y.cpu().numpy()[
               :, 0, 1], color='blue', label='sampled data', s=1)
  
  if pred_y is not None:
    ax.plot(pred_y.cpu().numpy()[:, 0, 0], pred_y.cpu().numpy()[:, 0, 1], 'red', label='learned trajectory')
    ax2.plot(t.cpu().numpy(), pred_y.cpu().numpy()[:, 0, 0], '--', t.cpu().numpy(), pred_y.cpu().numpy()[:, 0, 1], 'b--')

  ax.set_xlim(0, 1.5)
  ax.set_ylim(0, 3)

  ax2.set_xlim(t.cpu().min(), t.cpu().max())
  ax2.set_ylim(0, 3)
  ax.legend()
  ax2.grid(True)
  plt.show()

visualize(true_y, noisy_y)

# %% [markdown]
# # Training

# %%
batch_time = 20
batch_size = 32

def get_batch():
  s = torch.from_numpy(np.random.choice(np.arange(data_size - batch_time, dtype=np.int64), batch_size, replace=False))
  batch_y0 = noisy_y[s]  # (batch_size, 1, emb)
  batch_t = t[:batch_time]  # (T)
  batch_y = torch.stack([noisy_y[s + i] for i in range(batch_time)], dim=0)  # (time, batch_size, 1, emb)
  return batch_y0.cuda(), batch_t.cuda(), batch_y.cuda()

# %%
# define dynamic function
class ODEFunc(nn.Module):
  def __init__(self):
    super().__init__()
    self.net = nn.Sequential(nn.Linear(2, 32),
                             nn.SiLU(),
                             nn.Linear(32,32),
                             nn.SiLU(),
                             nn.Linear(32, 2))


  def forward(self, t, y):
    output = self.net(y)
    return output

# %%
from torchdiffeq import odeint_adjoint

## Train
niters = 400

func = ODEFunc().cuda()
optimizer = optim.RMSprop(func.parameters(), lr=1e-3)

start_time = time.time()

for iter in tqdm(range(niters + 1)):
  optimizer.zero_grad()
  batch_y0, batch_t, batch_y = get_batch()
  pred_y = odeint_adjoint(func = func, y0=batch_y0, t=batch_t, rtol=1e-7, atol=1e-9, method='dopri5')
  loss = torch.mean(torch.abs(pred_y - batch_y))
  loss.backward()
  optimizer.step()

  if iter % 200 == 0:
    with torch.no_grad():
      pred_y = odeint_adjoint(func, true_y0, t, rtol=1e-7, atol=1e-9, method='dopri5')
      loss = torch.mean(torch.abs(pred_y - noisy_y))
      print('Iter {:04d} | Total Loss {:.6f}'.format(iter, loss.item()))
      visualize(true_y, noisy_y, pred_y)

end_time = time.time() - start_time
print('process time: {} sec'.format(end_time))
# Out:
#   0%|          | 0/401 [00:00<?, ?it/s]
# Iter 0000 | Total Loss 0.614682
# Iter 0200 | Total Loss 0.160206
# Iter 0400 | Total Loss 0.063548
# process time: 74.59331345558167 sec

# %% [markdown]
# # Testing

# %%
import torch
def randbetween():
    # Create a tensor of shape (1, 2) with values between 0 and 1
    tensor_2d = torch.zeros(1, 2).uniform_(0, 1)
    # Scale and shift the first element to be between 0.2 and 1.4
    tensor_2d[:, 0] = tensor_2d[:, 0].mul(1.2).add(0.2)
    # Scale and shift the second element to be between 0.75 and 2.75
    tensor_2d[:, 1] = tensor_2d[:, 1].mul(2).add(0.75)
    return tensor_2d.cuda()

def randnotbetween():


    tensor_2d = torch.zeros(1, 2)

    # Define the ranges for the two elements
    range_1 = [0.2, 1.4]
    range_2 = [0.75, 2.75]

    # Generate random values within a larger region, and check if they are outside the constrained region
    num_attempts = 1000   # Define a fixed number of attempts
    for _ in range(num_attempts):
        # Generate values within a larger region
        value_1, value_2 = torch.rand(
            2) * torch.tensor([1.8, 2]) + torch.tensor([0.2, 0.75])
        # Check if the values are outside the constrained region
        if not (range_1[0] <= value_1 <= range_1[1] and range_2[0] <= value_2 <= range_2[1]):
            break   # If the values are outside the constrained region, terminate the loop

    # Set the values in the tensor
    tensor_2d[0, 0] = value_1
    tensor_2d[0, 1] = value_2


    return tensor_2d.cuda()

# %%
randnotbetween()
# Out:
# tensor([[1.6865, 1.5981]], device='cuda:0')

# %%
test_y0s_inside = [randbetween() for _ in range(5)]

test_y0s_outside = [randnotbetween() for _ in range(5)]
test_y0s_outside
# Out:
# [tensor([[1.6365, 2.6465]], device='cuda:0'),
#  tensor([[1.5260, 1.7257]], device='cuda:0'),
#  tensor([[1.5151, 2.6132]], device='cuda:0'),
#  tensor([[1.4388, 1.7130]], device='cuda:0'),
#  tensor([[1.7278, 2.2622]], device='cuda:0')]

# %%
for test_y0 in test_y0s_inside:
  with torch.no_grad():
    node = NeuralODE(func=func).cuda()
    test_y = node(y0=test_y0, t=t, solver=rk4)

  with torch.no_grad():
    node = NeuralODE(func=Lambda()).cuda()
    true_y = node(y0=test_y0, t=t, solver=rk4)
  
  print('Initial condition: ', test_y0)
  visualize(true_y=true_y, pred_y=test_y)
# Out:
# Initial condition:  tensor([[0.7177, 2.1063]], device='cuda:0')
# Initial condition:  tensor([[0.3706, 1.1002]], device='cuda:0')
# Initial condition:  tensor([[0.8212, 0.8638]], device='cuda:0')
# Initial condition:  tensor([[0.4593, 2.1900]], device='cuda:0')
# Initial condition:  tensor([[1.0421, 2.2236]], device='cuda:0')

# %%
for test_y0 in test_y0s_outside:
  with torch.no_grad():
    node = NeuralODE(func=func).cuda()
    test_y = node(y0=test_y0, t=t, solver=rk4)

  with torch.no_grad():
    node = NeuralODE(func=Lambda()).cuda()
    true_y = node(y0=test_y0, t=t, solver=rk4)

  print('Initial condition: ', test_y0)
  visualize(true_y=true_y, pred_y=test_y)
# Out:
# Initial condition:  tensor([[1.6365, 2.6465]], device='cuda:0')
# Initial condition:  tensor([[1.5260, 1.7257]], device='cuda:0')
# Initial condition:  tensor([[1.5151, 2.6132]], device='cuda:0')
# Initial condition:  tensor([[1.4388, 1.7130]], device='cuda:0')
# Initial condition:  tensor([[1.7278, 2.2622]], device='cuda:0')
